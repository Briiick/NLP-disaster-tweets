# %% [markdown]
# ### Predicting Disaster Or Not using Metafeatures
#
# Here, we use just meta-feature data to predict disaster Tweets. This is an alternative method that is being tested. My hypothesis is that it won't be as good as one of the BERT models, however, it is still interesting to see how it performs. Also, perhaps to improve on BERT such data could be combined in some way to add more features.

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from sklearn.svm import SVC
from sklearn import feature_extraction, preprocessing, linear_model, decomposition, model_selection, metrics, pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from nltk import word_tokenize
from pandas_profiling import ProfileReport
import scikitplot as skplt
import string
import random
import re
import nltk
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer
from wordcloud import WordCloud, STOPWORDS
import transformers
from transformers import BertModel, BertTokenizer, TFBertModel, TFBertForSequenceClassification, BertConfig, AdamW, get_linear_schedule_with_warmup
import torch
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.layers import Input, Embedding, LSTM, GRU, Bidirectional, Dense, Dropout, Conv1D, GlobalMaxPool1D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import bert
import sys
import os
sys.path.append('../utility')
import utils

# seaborn settings
sns.set_theme(style="whitegrid")
np.random.seed(1)
torch.manual_seed(1)

# %%
# download pickles
train_df = pd.read_pickle("../data/pickles/clean_train_data.pkl")
test_df = pd.read_pickle("../data/pickles/clean_test_data.pkl")

# %%
# create final dfs without text col
train_labels = train_df['target']
final_train_df = train_df.drop(columns=['text', 'id', 'target'])
final_test_df = test_df.drop(columns=['text', 'id'])

# %% [markdown]
# **Non-text data: final expansion of metafeatures using one-hot encoding to make them less revelant in model.**
#
# In order to incorporate our metafeatures into our modelling, we need to introduce them to a neural network after out BERT modelling. This is because they won't be interpreted correctly otherwise. We can prepare them here by simply normalising using `MinMaxScaler()`.

# %%
# normalise columns
scaler = MinMaxScaler()
final_train_df = scaler.fit_transform(final_train_df)
final_test_df = scaler.fit_transform(final_test_df)

# %% [markdown]
# **Get labels and train-test split.**

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(final_train_df, train_labels, test_size=0.3, random_state=42)

# %%
# create CNN
model = Sequential()
model.add(Dense(90, input_dim=9, activation='relu'))
model.add(Dense(120, activation='relu'))
model.add(Dense(100))
model.add(Dense(20, activation='relu'))

model.add(Dense(1, activation='sigmoid'))

# adam optimizer
optimizer = tf.keras.optimizers.Adam(lr=1e-4)

# compile and summarise
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
model.summary()

# first fit is history1
history = model.fit(X_train, y_train, epochs=100, batch_size=35, validation_data=(X_test, y_test), verbose=1)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 90)                900
# _________________________________________________________________
# dense_16 (Dense)             (None, 120)               10920
# _________________________________________________________________
# dense_17 (Dense)             (None, 100)               12100
# _________________________________________________________________
# dense_18 (Dense)             (None, 20)                2020
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 21
# =================================================================
# Total params: 25,961
# Trainable params: 25,961
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 149/149 [==============================] - 5s 12ms/step - loss: 0.6845 - accuracy: 0.5593 - val_loss: 0.6697 - val_accuracy: 0.5669
# Epoch 2/100
# 149/149 [==============================] - 1s 7ms/step - loss: 0.6586 - accuracy: 0.5977 - val_loss: 0.6515 - val_accuracy: 0.6416
# Epoch 3/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.6484 - accuracy: 0.6336 - val_loss: 0.6371 - val_accuracy: 0.6483
# Epoch 4/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.6415 - accuracy: 0.6357 - val_loss: 0.6306 - val_accuracy: 0.6497
# Epoch 5/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.6239 - accuracy: 0.6505 - val_loss: 0.6272 - val_accuracy: 0.6577
# Epoch 6/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.6246 - accuracy: 0.6570 - val_loss: 0.6245 - val_accuracy: 0.6577
# Epoch 7/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.6259 - accuracy: 0.6538 - val_loss: 0.6240 - val_accuracy: 0.6564
# Epoch 8/100
# 149/149 [==============================] - 1s 8ms/step - loss: 0.6195 - accuracy: 0.6642 - val_loss: 0.6220 - val_accuracy: 0.6617
# Epoch 9/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.6148 - accuracy: 0.6683 - val_loss: 0.6200 - val_accuracy: 0.6640
# Epoch 10/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.6163 - accuracy: 0.6639 - val_loss: 0.6193 - val_accuracy: 0.6631
# Epoch 11/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.6126 - accuracy: 0.6595 - val_loss: 0.6179 - val_accuracy: 0.6702
# Epoch 12/100
# 149/149 [==============================] - 1s 5ms/step - loss: 0.6180 - accuracy: 0.6634 - val_loss: 0.6167 - val_accuracy: 0.6725
# Epoch 13/100
# 149/149 [==============================] - 1s 7ms/step - loss: 0.6181 - accuracy: 0.6665 - val_loss: 0.6159 - val_accuracy: 0.6667
# Epoch 14/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.6127 - accuracy: 0.6687 - val_loss: 0.6168 - val_accuracy: 0.6658
# Epoch 15/100
# 149/149 [==============================] - 1s 5ms/step - loss: 0.6184 - accuracy: 0.6625 - val_loss: 0.6145 - val_accuracy: 0.6676
# Epoch 16/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.6098 - accuracy: 0.6693 - val_loss: 0.6143 - val_accuracy: 0.6725
# Epoch 17/100
# 149/149 [==============================] - 1s 5ms/step - loss: 0.6020 - accuracy: 0.6788 - val_loss: 0.6129 - val_accuracy: 0.6702
# Epoch 18/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.6076 - accuracy: 0.6811 - val_loss: 0.6122 - val_accuracy: 0.6738
# Epoch 19/100
# 149/149 [==============================] - 1s 5ms/step - loss: 0.6138 - accuracy: 0.6654 - val_loss: 0.6165 - val_accuracy: 0.6680
# Epoch 20/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.6065 - accuracy: 0.6787 - val_loss: 0.6105 - val_accuracy: 0.6743
# Epoch 21/100
# 149/149 [==============================] - 1s 7ms/step - loss: 0.6130 - accuracy: 0.6611 - val_loss: 0.6105 - val_accuracy: 0.6747
# Epoch 22/100
# 149/149 [==============================] - 1s 8ms/step - loss: 0.6084 - accuracy: 0.6694 - val_loss: 0.6098 - val_accuracy: 0.6765
# Epoch 23/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.6082 - accuracy: 0.6685 - val_loss: 0.6112 - val_accuracy: 0.6752
# Epoch 24/100
# 149/149 [==============================] - 1s 7ms/step - loss: 0.6005 - accuracy: 0.6799 - val_loss: 0.6112 - val_accuracy: 0.6761
# Epoch 25/100
# 149/149 [==============================] - 1s 8ms/step - loss: 0.5999 - accuracy: 0.6818 - val_loss: 0.6106 - val_accuracy: 0.6743
# Epoch 26/100
# 149/149 [==============================] - 1s 8ms/step - loss: 0.5994 - accuracy: 0.6852 - val_loss: 0.6085 - val_accuracy: 0.6770
# Epoch 27/100
# 149/149 [==============================] - 1s 8ms/step - loss: 0.6018 - accuracy: 0.6778 - val_loss: 0.6106 - val_accuracy: 0.6738
# Epoch 28/100
# 149/149 [==============================] - 1s 7ms/step - loss: 0.6036 - accuracy: 0.6775 - val_loss: 0.6096 - val_accuracy: 0.6756
# Epoch 29/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.6026 - accuracy: 0.6723 - val_loss: 0.6077 - val_accuracy: 0.6774
# Epoch 30/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.5995 - accuracy: 0.6838 - val_loss: 0.6072 - val_accuracy: 0.6810
# Epoch 31/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.6076 - accuracy: 0.6716 - val_loss: 0.6089 - val_accuracy: 0.6729
# Epoch 32/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.6079 - accuracy: 0.6768 - val_loss: 0.6071 - val_accuracy: 0.6832
# Epoch 33/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.6029 - accuracy: 0.6832 - val_loss: 0.6071 - val_accuracy: 0.6796
# Epoch 34/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5957 - accuracy: 0.6731 - val_loss: 0.6113 - val_accuracy: 0.6694
# Epoch 35/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5959 - accuracy: 0.6808 - val_loss: 0.6096 - val_accuracy: 0.6720
# Epoch 36/100
# 149/149 [==============================] - 1s 3ms/step - loss: 0.6095 - accuracy: 0.6725 - val_loss: 0.6063 - val_accuracy: 0.6787
# Epoch 37/100
# 149/149 [==============================] - 1s 5ms/step - loss: 0.5937 - accuracy: 0.6838 - val_loss: 0.6076 - val_accuracy: 0.6819
# Epoch 38/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.6043 - accuracy: 0.6721 - val_loss: 0.6064 - val_accuracy: 0.6850
# Epoch 39/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5992 - accuracy: 0.6889 - val_loss: 0.6084 - val_accuracy: 0.6720
# Epoch 40/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5946 - accuracy: 0.6847 - val_loss: 0.6074 - val_accuracy: 0.6752
# Epoch 41/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5961 - accuracy: 0.6844 - val_loss: 0.6085 - val_accuracy: 0.6716
# Epoch 42/100
# 149/149 [==============================] - 1s 3ms/step - loss: 0.6002 - accuracy: 0.6794 - val_loss: 0.6062 - val_accuracy: 0.6792
# Epoch 43/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5880 - accuracy: 0.6963 - val_loss: 0.6060 - val_accuracy: 0.6855
# Epoch 44/100
# 149/149 [==============================] - 1s 5ms/step - loss: 0.5973 - accuracy: 0.6772 - val_loss: 0.6088 - val_accuracy: 0.6725
# Epoch 45/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.6014 - accuracy: 0.6830 - val_loss: 0.6075 - val_accuracy: 0.6770
# Epoch 46/100
# 149/149 [==============================] - 1s 5ms/step - loss: 0.5967 - accuracy: 0.6875 - val_loss: 0.6069 - val_accuracy: 0.6805
# Epoch 47/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.6053 - accuracy: 0.6727 - val_loss: 0.6051 - val_accuracy: 0.6805
# Epoch 48/100
# 149/149 [==============================] - 0s 3ms/step - loss: 0.6056 - accuracy: 0.6771 - val_loss: 0.6044 - val_accuracy: 0.6881
# Epoch 49/100
# 149/149 [==============================] - 0s 3ms/step - loss: 0.5977 - accuracy: 0.6886 - val_loss: 0.6066 - val_accuracy: 0.6814
# Epoch 50/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5965 - accuracy: 0.6881 - val_loss: 0.6050 - val_accuracy: 0.6787
# Epoch 51/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5922 - accuracy: 0.6789 - val_loss: 0.6051 - val_accuracy: 0.6796
# Epoch 52/100
# 149/149 [==============================] - 0s 3ms/step - loss: 0.5921 - accuracy: 0.6851 - val_loss: 0.6051 - val_accuracy: 0.6922
# Epoch 53/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5879 - accuracy: 0.6938 - val_loss: 0.6040 - val_accuracy: 0.6828
# Epoch 54/100
# 149/149 [==============================] - 0s 3ms/step - loss: 0.6007 - accuracy: 0.6841 - val_loss: 0.6094 - val_accuracy: 0.6819
# Epoch 55/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5910 - accuracy: 0.6921 - val_loss: 0.6061 - val_accuracy: 0.6922
# Epoch 56/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5988 - accuracy: 0.6905 - val_loss: 0.6050 - val_accuracy: 0.6832
# Epoch 57/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5887 - accuracy: 0.6959 - val_loss: 0.6079 - val_accuracy: 0.6859
# Epoch 58/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5830 - accuracy: 0.7029 - val_loss: 0.6052 - val_accuracy: 0.6895
# Epoch 59/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5880 - accuracy: 0.6937 - val_loss: 0.6042 - val_accuracy: 0.6841
# Epoch 60/100
# 149/149 [==============================] - 1s 3ms/step - loss: 0.5979 - accuracy: 0.6840 - val_loss: 0.6037 - val_accuracy: 0.6895
# Epoch 61/100
# 149/149 [==============================] - 0s 3ms/step - loss: 0.5910 - accuracy: 0.6908 - val_loss: 0.6058 - val_accuracy: 0.6935
# Epoch 62/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5906 - accuracy: 0.7003 - val_loss: 0.6072 - val_accuracy: 0.6756
# Epoch 63/100
# 149/149 [==============================] - 1s 3ms/step - loss: 0.6000 - accuracy: 0.6783 - val_loss: 0.6066 - val_accuracy: 0.6765
# Epoch 64/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5878 - accuracy: 0.6874 - val_loss: 0.6078 - val_accuracy: 0.6828
# Epoch 65/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5848 - accuracy: 0.7004 - val_loss: 0.6044 - val_accuracy: 0.6801
# Epoch 66/100
# 149/149 [==============================] - 1s 3ms/step - loss: 0.5932 - accuracy: 0.6843 - val_loss: 0.6044 - val_accuracy: 0.6846
# Epoch 67/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5845 - accuracy: 0.6834 - val_loss: 0.6060 - val_accuracy: 0.6765
# Epoch 68/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5890 - accuracy: 0.6895 - val_loss: 0.6042 - val_accuracy: 0.6908
# Epoch 69/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5787 - accuracy: 0.7044 - val_loss: 0.6039 - val_accuracy: 0.6779
# Epoch 70/100
# 149/149 [==============================] - 1s 3ms/step - loss: 0.5845 - accuracy: 0.6979 - val_loss: 0.6082 - val_accuracy: 0.6747
# Epoch 71/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5914 - accuracy: 0.6940 - val_loss: 0.6067 - val_accuracy: 0.6872
# Epoch 72/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5833 - accuracy: 0.7019 - val_loss: 0.6039 - val_accuracy: 0.6872
# Epoch 73/100
# 149/149 [==============================] - 1s 4ms/step - loss: 0.5901 - accuracy: 0.6895 - val_loss: 0.6033 - val_accuracy: 0.6846
# Epoch 74/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.5922 - accuracy: 0.6910 - val_loss: 0.6128 - val_accuracy: 0.6765
# Epoch 75/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.5912 - accuracy: 0.6861 - val_loss: 0.6028 - val_accuracy: 0.6832
# Epoch 76/100
# 149/149 [==============================] - 1s 5ms/step - loss: 0.5816 - accuracy: 0.7000 - val_loss: 0.6029 - val_accuracy: 0.6872
# Epoch 77/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.5896 - accuracy: 0.6910 - val_loss: 0.6033 - val_accuracy: 0.6837
# Epoch 78/100
# 149/149 [==============================] - 1s 5ms/step - loss: 0.5926 - accuracy: 0.6911 - val_loss: 0.6035 - val_accuracy: 0.6859
# Epoch 79/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.5799 - accuracy: 0.7084 - val_loss: 0.6034 - val_accuracy: 0.6837
# Epoch 80/100
# 149/149 [==============================] - 1s 7ms/step - loss: 0.5792 - accuracy: 0.7114 - val_loss: 0.6038 - val_accuracy: 0.6895
# Epoch 81/100
# 149/149 [==============================] - 1s 7ms/step - loss: 0.5760 - accuracy: 0.7030 - val_loss: 0.6037 - val_accuracy: 0.6846
# Epoch 82/100
# 149/149 [==============================] - 1s 7ms/step - loss: 0.5817 - accuracy: 0.6940 - val_loss: 0.6051 - val_accuracy: 0.6859
# Epoch 83/100
# 149/149 [==============================] - 1s 7ms/step - loss: 0.5823 - accuracy: 0.7014 - val_loss: 0.6029 - val_accuracy: 0.6895
# Epoch 84/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.5796 - accuracy: 0.6974 - val_loss: 0.6027 - val_accuracy: 0.6864
# Epoch 85/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.5873 - accuracy: 0.6959 - val_loss: 0.6032 - val_accuracy: 0.6886
# Epoch 86/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.5856 - accuracy: 0.6920 - val_loss: 0.6035 - val_accuracy: 0.6841
# Epoch 87/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.5942 - accuracy: 0.6862 - val_loss: 0.6058 - val_accuracy: 0.6752
# Epoch 88/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.5929 - accuracy: 0.6882 - val_loss: 0.6025 - val_accuracy: 0.6846
# Epoch 89/100
# 149/149 [==============================] - 1s 5ms/step - loss: 0.5859 - accuracy: 0.6976 - val_loss: 0.6165 - val_accuracy: 0.6644
# Epoch 90/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.5862 - accuracy: 0.6843 - val_loss: 0.6035 - val_accuracy: 0.6828
# Epoch 91/100
# 149/149 [==============================] - 1s 5ms/step - loss: 0.5855 - accuracy: 0.6894 - val_loss: 0.6023 - val_accuracy: 0.6904
# Epoch 92/100
# 149/149 [==============================] - 1s 7ms/step - loss: 0.5927 - accuracy: 0.6887 - val_loss: 0.6031 - val_accuracy: 0.6913
# Epoch 93/100
# 149/149 [==============================] - 1s 5ms/step - loss: 0.5759 - accuracy: 0.7045 - val_loss: 0.6060 - val_accuracy: 0.6850
# Epoch 94/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.5835 - accuracy: 0.7009 - val_loss: 0.6086 - val_accuracy: 0.6743
# Epoch 95/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.5790 - accuracy: 0.7062 - val_loss: 0.6039 - val_accuracy: 0.6837
# Epoch 96/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.5847 - accuracy: 0.6999 - val_loss: 0.6039 - val_accuracy: 0.6935
# Epoch 97/100
# 149/149 [==============================] - 1s 5ms/step - loss: 0.5755 - accuracy: 0.7059 - val_loss: 0.6043 - val_accuracy: 0.6886
# Epoch 98/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.5860 - accuracy: 0.7027 - val_loss: 0.6060 - val_accuracy: 0.6756
# Epoch 99/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.5747 - accuracy: 0.7083 - val_loss: 0.6086 - val_accuracy: 0.6779
# Epoch 100/100
# 149/149 [==============================] - 1s 6ms/step - loss: 0.5877 - accuracy: 0.6974 - val_loss: 0.6027 - val_accuracy: 0.6890

# %%
plt.figure(figsize=(16, 10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(16, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# predictions
test_pred = model.predict(X_test)
print(test_pred)
# Out:
# [[0.70873123]
#  [0.45126972]
#  [0.74411875]
#  ...
#  [0.39939198]
#  [0.60940963]
#  [0.41375178]]

# %%
# this checks if the probability of disaster is above 0.5. If so, we label 1.
test_pred_bool = test_pred.copy().astype(int)
for index in range(len(test_pred)): 
    if test_pred[index]>0.5:
        test_pred_bool[index]=1
    else:
        test_pred_bool[index]=0

# %%
final_predictions = test_pred_bool.flatten()

# %%
# model test function
def eval_model(predictions):
    print(accuracy_score(y_test, predictions))
    # Compute fpr, tpr, thresholds and roc auc
    fpr, tpr, thresholds = roc_curve(np.array(y_test), np.array(predictions))
    roc_auc = auc(fpr, tpr)

    # Plot ROC curve
    plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')  # random predictions curve
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate or (1 - Specifity)')
    plt.ylabel('True Positive Rate or (Sensitivity)')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.show()
    print(classification_report(y_test, np.array(predictions), target_names=["not disaster", "disaster"]))

# %%
eval_model(final_predictions)
# Out:
# 0.6890380313199105
#               precision    recall  f1-score   support
#
# not disaster       0.72      0.75      0.73      1271
#     disaster       0.65      0.61      0.63       964
#
#     accuracy                           0.69      2235
#    macro avg       0.68      0.68      0.68      2235
# weighted avg       0.69      0.69      0.69      2235

# %%
# actual test predictions
real_pred = model.predict(final_test_df)
print(real_pred)
# Out:
# [[0.27532917]
#  [0.45477903]
#  [0.25764644]
#  ...
#  [0.46438268]
#  [0.60987705]
#  [0.5139907 ]]

# %%
# this checks if the probability of disaster is above 0.5. If so, we label 1.
real_pred_bool = real_pred.copy().astype(int)
for index in range(len(real_pred)): 
    if real_pred[index]>0.5:
        real_pred_bool[index]=1
    else:
        real_pred_bool[index]=0

# %%
real_predictions = real_pred_bool.flatten()

# %% [markdown]
# As hypothesized, the method using meta-features hasn't done as well as BERT.

# %% [markdown]
# ### Preparing Kaggle Submission

# %% [markdown]
# All we need to do now is turn our output probabilities of our machine learning model into boolean values and submit the predictions!

# %%
submission = pd.read_csv("../data/submissions/submission.csv")
submission["target"] = real_predictions
submission.to_csv('../data/submissions/submission-meta.csv', index=False)

# %% [markdown]
# To submit, we use the Kaggle API and type the following:
#
# `kaggle competitions submit -c nlp-getting-started -f submission.csv -m "Message"`
